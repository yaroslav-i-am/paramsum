# %%
from pprint import pprint

# %%
resps = [
    {'id': 'd7q7ka6lpq8li96rv0rp', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:21:53Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:21:55Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков с описанием характера персонажей из рецензии на фильм:\n\n1. По-настоящему живой фильм, держит все свои 118 минут как на одном дыхании!\n\n2. Драма, триллер, боевик — да, в этом фильме есть всё это и не только!\n\n3. Так хотелось увидеть продолжение фильма, но концовка данного произведения этого не подразумевает… Увы!'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '193', 'completionTokens': '79', 'totalTokens': '272'}, 'modelVersion': '18.01.2024'}},
    {'id': 'd7qb1lu09bbca1u6arsc', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:21:56Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:21:59Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков из рецензии, в которых содержится описание игры актёров:\n\n1. *«Можно возразить, что Люди Икс были экранизированы значительно раньше и сразу немалой командой».*\n\n2. *«Понятно, что такие разные персонажи не могут просто так взять и начать работать вместе».*\n\n3. *«Но вот причины, из-за которых они ссорятся, почти всегда надуманны».*\n\n4. *«Да и непрофессионализм сверхсекретной организации Щ.И.Т. тоже впечатляет».*\n\nНи один из этих отрывков не содержит информации о том, что актёры отлично справились со своей работой или, наоборот, не смогли передать характер персонажей. В рецензии указано, что персонажи получились «донельзя картонными». Ответ: **None**.'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '303', 'completionTokens': '159', 'totalTokens': '462'}, 'modelVersion': '18.01.2024'}},
    {'id': 'd7qg3con0mo516gp937s', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:22:00Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:22:02Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков из рецензии, в которых содержится описание декораций фильма «Запах женщины»:\n* Два взгляда столкнулись на море…\n* Чтоб станцевать танго под луною…\n* Под звуки музыки с шумящею волною…\n* …Под пароход, стремящийся к прибою…\n* Окунувшись в свежий ветер с головою…\n* Забыться, закружиться в глубине ночной…\n* И спрятаться от жизни бестолковой, ледяной…\n\nНи один из этих отрывков не содержит новой информации, это лишь пересказ рецензии.\n\n**None**\n\nЕсли искомой информации нет в приведённом отрывке, то можно попробовать найти её в других частях рецензии.'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '291', 'completionTokens': '145', 'totalTokens': '436'}, 'modelVersion': '18.01.2024'}},
    {'id': 'd7qcsl7ov8tmm8jhc8o2', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:22:03Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:22:06Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков из рецензии, в которых описывается игра актёров:\n\n1. *«В каждом актёре угадывается свой неповторимый стиль игры, но их роли словно бы написаны под них.»*\n\n2. *«Каждый актёр на своём месте, будь то Киану Ривз, восставший из пепла, но не менее опасный, или же нестареющий Уиллем Дефо (которого, впрочем, трудно представить молодым).»*\n\n3. *«…Или же Иэн МакШейн, чьему появлению на экране не устаёшь радоваться.»*\n4. *«Отдельно стоит отметить Микаэла Нюквиста, который недавно ворвался в Голливуд и берёт лёгкой надменностью и иронией.»_\n5. *«Элфи Оуэн-Аллен… о, я запомню его лицо надолго, причём оно для меня станет нарицательным.»*'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '596', 'completionTokens': '176', 'totalTokens': '772'}, 'modelVersion': '18.01.2024'}},
    {'id': 'd7qv4n77ul6ji141au7d', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:22:06Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:22:09Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков, в которых содержится описание игры актёров:\n\n1. *«В роли Эвелин выступила актриса Рэйчел Вайс, чья героиня — прехорошенькая, миловидная девушка, умная и просвещённая, знаток древнеегипетской истории и письма (иероглифов), библиотекарь по профессии, неунывающая искательница приключений по призванию».*\n\n2. *«В роли её неугомонного брата выступил Джонни Ханна, чей персонаж — несколько трусливый, словоохотливый, разглагольствующий на любые темы в минуты опасности, чтобы хоть как-то успокоить свои внутренние треволнения».*\n\n3. *«Роль Ричарда О’Коннела на себя примерил несравненный Брендан Фрейзер, герой которого — решительный, мужественный, всёляющий надежду и уверенность, здравомыслящий и малоразговорчивый молодой человек с еле заметной полуулыбкой на губах».*'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens':
ю фильму положительную рецензию, ибо в нём, хоть и весьма мрачно и утрированно показана наша жизнь.\n\n**Ни в одном из этих отрывков нет информации, которую можно было бы назвать новой. Все эти утверждения — лишь субъективное мнение автора рецензии о фильме.**\n\nЕсли из рецензии убрать все субъективные оценки, то она может выглядеть так:\n\n«Дурак» — фильм российского режиссёра Юрия Быкова. Действие фильма происходит в одном из провинциальных городов России. Главный герой фильма — сантехник по имени Женя. Женя живёт в общежитии, где царит нищета и разруха. Он пытается помочь своим соседям, но его попытки оказываются тщетными. В конце фильма Женя решает спасти своих соседей, но это приводит к его гибели.\n\nФильм «Дурак» получил неоднозначные отзывы критиков. Одни критики хвалят фильм за его реалистичное изображение российской действительности, другие критикуют фильм за его пессимизм и безысходность.\n\n**В этом описании нет описаний игры актёров, оно лишь кратко излагает сюжет фильма.**'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '787', 'completionTokens': '389', 'totalTokens': '1176'}, 'modelVersion': '18.01.2024'}},
    {'id': 'd7q5om3cqvca9vdn3urs', 'description': 'Async GPT Completion', 'createdAt': '2024-04-29T07:22:42Z', 'createdBy': 'aje93q2j6d3j5thplmll', 'modifiedAt': '2024-04-29T07:22:44Z', 'done': True, 'metadata': None, 'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse', 'alternatives': [{'message': {'role': 'assistant', 'text': 'Вот список отрывков из рецензии, в которых содержится описание игры актёров:\n\n1. «Кот в Сапогах. Этот герой является одной из самых весомых причин, посмотреть этот мультик. Он мил до невозможности».\n\n2. «Антонио Бандерас придаёт ему отдельного испанского шарма».\n\n3. «Но в некоторых случая, как например пуканья на цветы, появляется чувство отвращения».'}, 'status': 'ALTERNATIVE_STATUS_FINAL'}], 'usage': {'inputTextTokens': '412', 'completionTokens': '85', 'totalTokens': '497'}, 'modelVersion': '18.01.2024'}}
]

# %%
pprint(resps)
# Out:
# [{'createdAt': '2024-04-29T07:21:53Z',
#   'createdBy': 'aje93q2j6d3j5thplmll',
#   'description': 'Async GPT Completion',
#   'done': True,
#   'id': 'd7q7ka6lpq8li96rv0rp',
#   'metadata': None,
#   'modifiedAt': '2024-04-29T07:21:55Z',
#   'response': {'@type': 'type.googleapis.com/yandex.cloud.ai.foundation_models.v1.CompletionResponse',
#                'alternatives': [{'message': {'role': 'assistant',
#                                              'text': 'Вот список отрывков с '
#                                                      'описанием характера '
#                                                      'персонажей из рецензии '
#                                                      'на фильм:\n'
#                                                      '\n'
#                                                      '1. По-настоящему живой '
#                                                      'фильм, держит все свои '
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
gold, silver = pd.read_csv('./paramsum/data/working_dir/ready_markup.csv'), pd.read_csv('./paramsum/data/working_dir/gpt_markup.csv')

# %%
gold
# Out:
#                                  aspect  \
# 0          описание личности персонажей
# 1                 описание игры актёров
# 2          описание декораций и графики
# 3                 описание игры актёров
# 4                 описание игры актёров
# ..                                  ...
# 94  характеристика внешности персонажей
# 95  описание эмоций от просмотра фильма
# 96         описание декораций и графики
# 97              философские рассуждения
# 98             мнение о музыке в фильме
#
#                                                review  \
# 0   По-настоящему живой фильм, держит все свои 118...
# 1     Мстители   стал первым экспериментом по сбор...
# 2   Два взгляда столкнулись на море,    Чтоб станц...
# 3   Жена главного героя, собственно Джона Уика, уш...
# 4   'Мумия' - фантастическая комедийная история о ...
# ..                                                ...
# 94  Как много в кинематографе переоцененных фильмо...
# ...

# %%
gold['gpt_markup'] = None
gold['gpt_markup'] = silver

# %%
silver
# Out:
#                                            gpt_markup
# 0                                                 NaN
# 1   * Описание игры актёров, мнение об актёре или ...
# 2                                                 NaN
# 3   В каждом актёре угадывается свой неповторимый ...
# 4   * В роли Эвелин выступила актриса Рейчел Вайс,...
# ..                                                ...
# 94                                                NaN
# 95  В рецензии описывается трогательная история, н...
# 96  В рецензии нет описания декораций и графики.\n...
# 97  В рецензии встречаются следующие философские р...
# 98  В рецензии не упоминается музыка в фильме.\n\n...
#
# [99 rows x 1 columns]

# %%
print(gold.aspect.value_counts())
g = sns.barplot(y=gold.aspect.value_counts(), x=gold.aspect.value_counts().index, palette='Blues')
g.set_xticklabels(labels=gold.aspect.value_counts().index, rotation=45, horizontalalignment='right');
# Out:
# aspect
# описание игры актёров                  17
# характеристика внешности персонажей    13
# описание личности персонажей           12
# описание декораций и графики           12
# философские рассуждения                12
# описание эмоций от просмотра фильма    11
# общее мнение о фильме                   8
# мнение о музыке в фильме                8
# мнение о режиссёре                      6
# Name: count, dtype: int64
# D:\ProgramData\anaconda3\envs\kaggle\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramData\anaconda3\envs\kaggle\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
gold.review.iloc[4]
# Out:
# "'Мумия' - фантастическая комедийная история о приключениях в Египте. Пожалуй, лучшей истории об ожившем древнеегипетском жреце и его приближенных не сыскать. Каждый раз, когда телевидение решает вновь показать кино 1999-ого года выпуска, я, не взирая на время и усталость, бросаю все дела и сажусь в 100-тысячный раз его посмотреть.        Итак, в первую очередь, это история о брате и сестре - Джонатане и Эвелин, которые однажды, загоревшись мыслью, во что бы то ни стало, отыскать древнеегипетский город мертвых - Хамунаптру, отправляются в Египет, а в качестве сопровождающего берут себе некоего Ричарда О Коннела, которому уже 'посчастливилось' побывать в этом злополучном месте.        В роли Эвелин выступила актриса Рейчел Вайс, чья героиня - прехорошенькая, миловидная девушка, умная и просвещенная, знаток древнеегипетской истории и письма (иероглифов), библиотекарь по профессии, неунывающая искательница приключений по призванию.        В роли её неугомонного брата выступил Джонн Ханн
# ...

# %%
for i in range(len(silver)):
    print(i)
    print(gold['aspect'].iloc[i], '\n')

    print(gold['answers'].iloc[i])
    print(gold['gpt_markup'].iloc[i])
    print('\n---------------------------------------------\n')
# Out:
# 0
# описание личности персонажей
#
# {'затронуты как личностный аспект человека и его жизненная драма'}
# nan
#
# ---------------------------------------------
#
# 1
# описание игры актёров
#
# {'Собственно сам сбор персонажей, и то какие между ними возникают конфликты показано весьма неплохо, хотя и очень скомкано. Понятно что такие разные персонажи не могут просто так взять и начать работать вместе', 'персонажи получились донельзя картонными'}
# * Описание игры актёров, мнение об актёре или то, как получился персонаж, в рецензии отсутствует.
#
# * None
#
# ---------------------------------------------
#
# 2
# описание декораций и графики
#
# {'-'}
# nan
#
# ---------------------------------------------
#
# 3
# описание игры актёров
#
# ...
