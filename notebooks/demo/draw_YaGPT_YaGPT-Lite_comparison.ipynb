# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import trange, tqdm
tqdm.pandas()

# %%
markup_gpt = pd.read_csv('../data/working_dir/gpt/markup_preprocessed_with_metrics.csv')
markup_gpt_lite = pd.read_csv('../data/working_dir/gpt-lite/markup_preprocessed_with_metrics.csv')

print(markup_gpt.shape, markup_gpt_lite.shape)
markup_gpt
# Out:
# (99, 19) (99, 19)
#                                  aspect  \
# 0          описание личности персонажей
# 1                 описание игры актёров
# 2          описание декораций и графики
# 3                 описание игры актёров
# 4                 описание игры актёров
# ..                                  ...
# 94  характеристика внешности персонажей
# 95  описание эмоций от просмотра фильма
# 96         описание декораций и графики
# 97              философские рассуждения
# 98             мнение о музыке в фильме
#
#                                                review  \
# 0   По-настоящему живой фильм, держит все свои 118...
# 1     Мстители   стал первым экспериментом по сбор...
# 2   Два взгляда столкнулись на море,    Чтоб станц...
# 3   Жена главного героя, собственно Джона Уика, уш...
# 4   'Мумия' - фантастическая комедийная история о ...
# ..                                                ...
# 94  Как много в кинематографе переоцененных фильмо...
# 95  Как много в кинематографе переоцененных фильмо...
# 96  Как много в кинематографе переоцененных фильмо...
# 97  Как много в кинематографе переоцененных фильмо...
# 98  Как много в кинематографе переоцененных фильмо...
#
#                                               answers  \
# 0   {'затронуты как личностный аспект человека и е...
# 1   {'Собственно сам сбор персонажей, и то какие м...
# 2                                               {'-'}
# 3   {'Микаэл Нюквист  , недавно ворвавшийся в Голл...
# 4   {'Есть еще нимало незаурядных личностей, котор...
# ..                                                ...
# 94                                              {'-'}
# 95  {'Лично я не растрогалась, глядя на людей. Рас...
# 96                                              {'-'}
# 97                                              {'-'}
# 98                                              {'-'}
#
#                                            gpt_markup  \
# 0                                                 NaN
# 1   * Описание игры актёров, мнение об актёре или ...
# 2                                                 NaN
# 3   В каждом актёре угадывается свой неповторимый ...
# 4   * В роли Эвелин выступила актриса Рейчел Вайс,...
# ..                                                ...
# 94                                                NaN
# 95                                             *None*
# 96                                             *None*
# 97  В рецензии встречаются следующие философские р...
# 98  В рецензии не упоминается музыка в фильме.\n\n...
#
#                               gpt_markup_preprocessed  \
# 0                                               {'-'}
# 1                                               {'-'}
# 2                                               {'-'}
# 3   {'Киану Ривз, восставший из пепла, но не менее...
# 4   {'В роли Эвелин выступила актриса Рейчел Вайс,...
# ..                                                ...
# 94                                              {'-'}
# 95                                              {'-'}
# 96                                              {'-'}
# 97  {'В рецензии встречаются следующие философские...
# 98                                              {'-'}
#
#                                 concat_full_bertscore  \
# 0   {'precision': [0.742644190788269], 'recall': [...
# 1   {'precision': [0.6771140098571777], 'recall': ...
# 2   {'precision': [1.0], 'recall': [1.0], 'f1': [1...
# 3   {'precision': [0.8908219933509827], 'recall': ...
# 4   {'precision': [0.7149181962013245], 'recall': ...
# ..                                                ...
# 94  {'precision': [1.0], 'recall': [1.0], 'f1': [1...
# 95  {'precision': [0.6965545415878296], 'recall': ...
# 96  {'precision': [1.0], 'recall': [1.0], 'f1': [1...
# 97  {'precision': [0.3215542137622833], 'recall': ...
# 98  {'precision': [1.0], 'recall': [1.0], 'f1': [1...
#
#                                      concat_full_chrf  \
# 0   {'score': 2.5502988275012544, 'char_order': 6,...
# 1   {'score': 0.6792878357130377, 'char_order': 6,...
# 2   {'score': 100.0, 'char_order': 6, 'word_order'...
# 3   {'score': 84.94295624736336, 'char_order': 6, ...
# 4   {'score': 23.73968001308012, 'char_order': 6, ...
# ..                                                ...
# 94  {'score': 100.0, 'char_order': 6, 'word_order'...
# 95  {'score': 0.5579948578413637, 'char_order': 6,...
# 96  {'score': 100.0, 'char_order': 6, 'word_order'...
# 97  {'score': 1.4818562510702553, 'char_order': 6,...
# 98  {'score': 100.0, 'char_order': 6, 'word_order'...
#
#                                     concat_full_rouge  \
# 0   {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 1   {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 2   {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 3   {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 4   {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# ..                                                ...
# 94  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 95  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 96  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 97  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 98  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
#
#                                      concat_full_bleu  \
# 0   {'bleu': 0.0, 'precisions': [0.8, 0.5, 0.0, 0....
# 1   {'bleu': 0.0, 'precisions': [0.8, 0.5, 0.0, 0....
# 2   {'bleu': 1.0, 'precisions': [1.0, 1.0, 1.0, 1....
# 3   {'bleu': 0.81485868555047, 'precisions': [0.88...
# 4   {'bleu': 0.09470423511543487, 'precisions': [0...
# ..                                                ...
# 94  {'bleu': 1.0, 'precisions': [1.0, 1.0, 1.0, 1....
# 95  {'bleu': 0.0, 'precisions': [0.8, 0.5, 0.0, 0....
# 96  {'bleu': 1.0, 'precisions': [1.0, 1.0, 1.0, 1....
# 97  {'bleu': 0.0, 'precisions': [0.011013215859030...
# 98  {'bleu': 1.0, 'precisions': [1.0, 1.0, 1.0, 1....
#
#     concat_precision_bert_score  concat_recall_bert_score  \
# 0                      0.742644                  0.530895
# 1                      0.677114                  0.393421
# 2                      1.000000                  1.000000
# 3                      0.890822                  0.890910
# 4                      0.714918                  0.747526
# ..                          ...                       ...
# 94                     1.000000                  1.000000
# 95                     0.696555                  0.386841
# 96                     1.000000                  1.000000
# 97                     0.321554                  0.627426
# 98                     1.000000                  1.000000
#
#     concat_f1_bert_score  concat_score_chrf  concat_rouge1  concat_rouge2  \
# 0               0.619166           2.550299            0.0            0.0
# 1               0.497678           0.679288            0.0            0.0
# 2               1.000000         100.000000            0.0            0.0
# 3               0.890866          84.942956            0.0            0.0
# 4               0.730858          23.739680            0.0            0.0
# ..                   ...                ...            ...            ...
# 94              1.000000         100.000000            0.0            0.0
# 95              0.497428           0.557995            0.0            0.0
# 96              1.000000         100.000000            0.0            0.0
# 97              0.425196           1.481856            0.0            0.0
# 98              1.000000         100.000000            0.0            0.0
#
#     concat_rougeL  concat_rougeLsum  concat_bleu  concat_brevity_penalty_bleu
# 0             0.0               0.0     0.000000                 2.491601e-05
# 1             0.0               0.0     0.000000                 2.115131e-19
# 2             0.0               0.0     1.000000                 1.000000e+00
# 3             0.0               0.0     0.814859                 1.000000e+00
# 4             0.0               0.0     0.094704                 1.000000e+00
# ..            ...               ...          ...                          ...
# 94            0.0               0.0     1.000000                 1.000000e+00
# 95            0.0               0.0     0.000000                 1.432552e-23
# 96            0.0               0.0     1.000000                 1.000000e+00
# 97            0.0               0.0     0.000000                 1.000000e+00
# 98            0.0               0.0     1.000000                 1.000000e+00
#
# [99 rows x 19 columns]

# %%
gpt_means = []
gpt_lite_means = []

for col in markup_gpt.columns[-10:]:
    gpt_mean = markup_gpt[col].mean()
    gpt_lite_mean = markup_gpt_lite[col].mean()

    gpt_means.append(gpt_mean)
    gpt_lite_means.append(gpt_lite_mean)
    
    print('\n\nMEAN:')
    print(f'YaGPT: {gpt_mean}')
    print(f'YaGPT-lite: {gpt_lite_mean}')
    plt.hist(markup_gpt[col], bins=100, label='YaGPT', alpha=0.5)
    plt.hist(markup_gpt_lite[col], bins=100, label='YaGPT-lite', alpha=0.5)
    plt.xlabel('samples')
    plt.ylabel(col)
    plt.legend()
    plt.show()

# plt.bar(markup_gpt.columns[-10:], gpt_means, label='YaGPT', alpha=0.5)
# plt.bar(markup_gpt.columns[-10:], gpt_lite_means, label='YaGPT-lite', alpha=0.5)
plt.bar(markup_gpt.columns[-10:], pd.Series(gpt_means) - pd.Series(gpt_lite_means), label='YaGPT - YaGPT-lite', alpha=0.5)
# Out:
# MEAN:
# YaGPT: 0.8062486221091916
# YaGPT-lite: 0.794440073196334
# MEAN:
# YaGPT: 0.8196023124637026
# YaGPT-lite: 0.7027997494948031
# MEAN:
# YaGPT: 0.8052138499539307
# YaGPT-lite: 0.7332179739017679
# MEAN:
# YaGPT: 50.25567377387134
# YaGPT-lite: 39.92129209482398
# MEAN:
# YaGPT: 0.020202020202020204
# YaGPT-lite: 0.010101010101010102
# MEAN:
# YaGPT: 0.010101010101010102
# YaGPT-lite: 0.010101010101010102
# MEAN:
# YaGPT: 0.020202020202020204
# YaGPT-lite: 0.010101010101010102
# MEAN:
# YaGPT: 0.020202020202020204
# YaGPT-lite: 0.010101010101010102
# MEAN:
# YaGPT: 0.43482517637677687
# YaGPT-lite: 0.36986939991516166
# MEAN:
# YaGPT: 0.8088547014704571
# YaGPT-lite: 0.5261325950565069
# <BarContainer object of 10 artists>
